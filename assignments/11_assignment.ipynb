# %% [markdown]
# # Image Processing SoSe 2026 - Assignment - 11
#
# ### Deadline is 09.07.2026 at 11:55 a.m.
#
# #### Students: NAME1 NAME2
#
# Please solve the assignments together with a partner.
#
# Make sure the code runs without errors, when clicking `Kernel` -> `Restart Kernel & Run All Cells`. Then save the notebook and upload your submission.

# %% [markdown]
# # Exercise 1 - Blending - 10 Points
#
# Blend two images (`fore.png`, `back.png`, see folder blending), by using pyramid blending. For simplicity, it is allowed to work on grayscale images.
# Create two Laplace pyramids for the foreground and background image.
# Create a Gaussian pyramid for the blending mask image `alpha.png`. Plot the lowest 3 levels of the three pyramids.
# Then apply pyramid blending. Show the lowest 3 levels of the resulting Laplace pyramid and reconstruct the image. Show the blended image.
#
# As an input you can use the images alpha.png, back.png, fore.png given  or use your own images.
# You should not use any blending functions or functions which create the Laplacian or Gaussian pyramid for you. Feel free to use a method
# of your own choice for the REDUCE and EXPAND function (see slides), especially for the interpolations. HINT: For simplicity you can use a REDUCE function which combines 2x2 pixels on one level to one pixel on the level above. The EXPAND function could create 2x2 pixels on a lower level from each pixel of the above level, accordingly.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage.color import rgb2gray

back = rgb2gray(np.array(Image.open('blending/back.png'))[:,:,0:3])
fore = rgb2gray(np.array(Image.open('blending/fore.png'))[:,:,0:3])
alpha = rgb2gray(np.array(Image.open('blending/alpha.png'))[:,:,0:3])

# plot the three images in jupyter
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(back, cmap='gray')
plt.subplot(1,3,2)
plt.imshow(fore, cmap='gray')
plt.subplot(1,3,3)
plt.imshow(alpha, cmap='gray')

# %%
def reduce():
    pass

def expand():
    pass

def laplace_pyramid(image, levels):
    pyramid = np.array([])
    return pyramid

def gaussian_pyramid(image, levels):
    pyramid = np.array([])
    return pyramid

def pyramid_blending(fore, back, alpha, levels):
    blended = np.array([])
    return blended

# plot the lowest three levels of the pyramid
# plot the lowest three levels of the resulting Laplace pyramid
# reconstruct the image
# show the blended image

# %% [markdown]
# Now blend, but not with the full pyramid as in a), instead use 2 levels and later 4 levels of the
# Laplacian / Gaussian pyramid, which only contains 2 or 4 levels.
#
# Plot the results (the blended images).

# %%
# plot the blended images
